# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("vivek468/superstore-dataset-final")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/superstore-dataset-final

# %%
import pandas as pd
data = pd.read_csv(path+ "/Sample - Superstore.csv", encoding='unicode_escape')

# %%
data
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.isna().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
data.drop("Row ID", axis = 1, inplace = True)
data.drop("Country", axis = 1, inplace = True)

# %%
data
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1     CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2     CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# ...              ...         ...         ...             ...         ...
# 9989  CA-2014-110422   1/21/2014   1/23/2014    Second Class    TB-21400
# 9990  CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9993  CA-2017-119914    5/4/2017    5/9/2017    Second Class    CC-12220
#
#          Customer Name    Segment             City       State  Postal Code  \
# ...

# %% [markdown]
# **After removing the "Row ID" row, we found that there is a duplicated row. So, we removed it**

# %%
data.duplicated().sum()
# Out:
# np.int64(1)

# %%
data[data.duplicated()]
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 3406  US-2014-150119  4/23/2014  4/27/2014  Standard Class    LB-16795
#
#        Customer Name      Segment      City State  Postal Code Region  \
# 3406  Laurel Beltran  Home Office  Columbus  Ohio        43229   East
#
#            Product ID   Category Sub-Category  \
# 3406  FUR-CH-10002965  Furniture       Chairs
#
#                                            Product Name    Sales  Quantity  \
# 3406  Global Leather Highback Executive Chair with P...  281.372         2
#
#       Discount   Profit
# 3406       0.3 -12.0588

# %%
data.drop_duplicates(inplace = True)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9993 entries, 0 to 9993
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9993 non-null   object
#  1   Order Date     9993 non-null   object
#  2   Ship Date      9993 non-null   object
#  3   Ship Mode      9993 non-null   object
#  4   Customer ID    9993 non-null   object
#  5   Customer Name  9993 non-null   object
#  6   Segment        9993 non-null   object
#  7   City           9993 non-null   object
#  8   State          9993 non-null   object
#  9   Postal Code    9993 non-null   int64
#  10  Region         9993 non-null   object
#  11  Product ID     9993 non-null   object
#  12  Category       9993 non-null   object
#  13  Sub-Category   9993 non-null   object
#  14  Product Name   9993 non-null   object
#  15  Sales          9993 non-null   float64
#  16  Quantity       9993 non-null   int64
# ...

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9993.000000   9993.000000  9993.000000  9993.000000  9993.000000
# mean   55191.576403    229.852846     3.789753     0.156188    28.660971
# std    32065.074478    623.276074     2.225149     0.206457   234.271476
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.731000
# 50%    56560.000000     54.480000     3.000000     0.200000     8.671000
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# **Changing "Order Data" & "Ship Date" to pd datetime**

# %%
data["Order Date"] = pd.to_datetime(data["Order Date"])
data["Ship Date"] = pd.to_datetime(data["Ship Date"])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9993 entries, 0 to 9993
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9993 non-null   object
#  1   Order Date     9993 non-null   datetime64[ns]
#  2   Ship Date      9993 non-null   datetime64[ns]
#  3   Ship Mode      9993 non-null   object
#  4   Customer ID    9993 non-null   object
#  5   Customer Name  9993 non-null   object
#  6   Segment        9993 non-null   object
#  7   City           9993 non-null   object
#  8   State          9993 non-null   object
#  9   Postal Code    9993 non-null   int64
#  10  Region         9993 non-null   object
#  11  Product ID     9993 non-null   object
#  12  Category       9993 non-null   object
#  13  Sub-Category   9993 non-null   object
#  14  Product Name   9993 non-null   object
#  15  Sales          9993 non-null   float64
#  16  Quantity       9993 non-null   int64
# ...

# %% [markdown]
# **The order that has the highest products**

# %%
data["Order ID"].value_counts()
# Out:
# Order ID
# CA-2017-100111    14
# CA-2017-157987    12
# CA-2016-165330    11
# US-2016-108504    11
# CA-2016-105732    10
#                   ..
# CA-2014-110422     1
# CA-2016-125794     1
# CA-2017-163566     1
# US-2015-151435     1
# CA-2016-130225     1
# Name: count, Length: 5009, dtype: int64

# %%
data["Customer Name"][data['Order ID'] == "CA-2017-100111"].unique()
# Out:
# array(['Seth Vernon'], dtype=object)

# %%
data["Ship Month"] = data['Ship Date'].dt.month
data["Ship Year"] = data['Ship Date'].dt.year

data["Order Month"] = data['Order Date'].dt.month
data["Order Year"] = data['Order Date'].dt.year

# %%
data
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2     CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# ...              ...        ...        ...             ...         ...
# 9989  CA-2014-110422 2014-01-21 2014-01-23    Second Class    TB-21400
# 9990  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9993  CA-2017-119914 2017-05-04 2017-05-09    Second Class    CC-12220
#
#          Customer Name    Segment             City       State  Postal Code  \
# ...

# %%
data['Order Year'].value_counts()
# Out:
# Order Year
# 2017    3312
# 2016    2587
# 2015    2102
# 2014    1992
# Name: count, dtype: int64

# %%
data['Order Year'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Order Year'>

# %%
data['Order Year'].value_counts().plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
data['Order Month'].value_counts(ascending=True)
# Out:
# Order Month
# 2      300
# 1      381
# 4      667
# 3      696
# 8      706
# 7      710
# 6      717
# 5      735
# 10     819
# 9     1383
# 12    1408
# 11    1471
# Name: count, dtype: int64

# %%
data['Order Month'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Order Month'>

# %%
data['Order Month'].value_counts().plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
data['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Standard Class    5967
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %%
data['Ship Mode'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Ship Mode'>

# %%
data
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2     CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# ...              ...        ...        ...             ...         ...
# 9989  CA-2014-110422 2014-01-21 2014-01-23    Second Class    TB-21400
# 9990  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9993  CA-2017-119914 2017-05-04 2017-05-09    Second Class    CC-12220
#
#          Customer Name    Segment             City       State  Postal Code  \
# ...

# %%
data['Customer ID'].value_counts()
# Out:
# Customer ID
# WB-21850    37
# MA-17560    34
# JL-15835    34
# PP-18955    34
# CK-12205    32
#             ..
# AO-10810     1
# LD-16855     1
# JR-15700     1
# CJ-11875     1
# RE-19405     1
# Name: count, Length: 793, dtype: int64

# %% [markdown]
# **The most frequent customer**

# %%
data['Customer Name'][data['Customer ID'] == "WB-21850"].unique()
# Out:
# array(['William Brown'], dtype=object)

# %%
data['Segment'].value_counts()
# Out:
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1782
# Name: count, dtype: int64

# %%
data['Segment'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
data['City'].value_counts()
# Out:
# City
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
#                 ...
# Abilene            1
# Montebello         1
# Kissimmee          1
# Danbury            1
# Springdale         1
# Name: count, Length: 531, dtype: int64

# %%
data['City'].value_counts().idxmax()
# Out:
# 'New York City'

# %%
data['City'].value_counts().idxmin()
# Out:
# 'Ontario'

# %%
data['State'].value_counts()
# Out:
# State
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     468
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
data['State'].value_counts().idxmax()
# Out:
# 'California'

# %%
data['State'].value_counts().idxmin()
# Out:
# 'Wyoming'

# %%
data['Region'].value_counts()
# Out:
# Region
# West       3203
# East       2847
# Central    2323
# South      1620
# Name: count, dtype: int64

# %%
data['Region'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Region'>

# %%
data.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'City', 'State', 'Postal Code', 'Region',
#        'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales',
#        'Quantity', 'Discount', 'Profit', 'Ship Month', 'Ship Year',
#        'Order Month', 'Order Year'],
#       dtype='object')

# %%
data['Product ID'].value_counts()
# Out:
# Product ID
# OFF-PA-10001970    19
# TEC-AC-10003832    18
# FUR-FU-10004270    16
# FUR-CH-10002647    15
# FUR-CH-10001146    15
#                    ..
# TEC-MA-10004552     1
# TEC-MA-10003589     1
# OFF-AP-10003099     1
# TEC-PH-10002645     1
# OFF-ST-10001627     1
# Name: count, Length: 1862, dtype: int64

# %% [markdown]
# **The most buying product name**

# %%
data['Product Name'][data['Product ID'] == "OFF-PA-10001970"].unique()
# Out:
# array(['Xerox 1881', 'Xerox 1908'], dtype=object)

# %%
data['Category'].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2120
# Technology         1847
# Name: count, dtype: int64

# %%
data['Category'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Category'>

# %%
data['Category'].value_counts().plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
data['Sub-Category'].value_counts()
# Out:
# Sub-Category
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          616
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %%
data['Sub-Category'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Sub-Category'>

# %%
data['Sales'].describe()
# Out:
# count     9993.000000
# mean       229.852846
# std        623.276074
# min          0.444000
# 25%         17.280000
# 50%         54.480000
# 75%        209.940000
# max      22638.480000
# Name: Sales, dtype: float64

# %% [markdown]
# **Get the Sales Outlier**

# %%
SalesLimit = data['Sales'].mean() + (3 * data['Sales'].std())
SalesLimit
# Out:
# np.float64(2099.681067398835)

# %%
data[data['Sales'] > SalesLimit]
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 27    US-2015-150630 2015-09-17 2015-09-21  Standard Class    TB-21520
# 165   CA-2014-139892 2014-09-08 2014-09-12  Standard Class    BM-11140
# 251   CA-2016-145625 2016-09-11 2016-09-17  Standard Class    KC-16540
# 262   US-2014-106992 2014-09-19 2014-09-21    Second Class    SB-20290
# 263   US-2014-106992 2014-09-19 2014-09-21    Second Class    SB-20290
# ...              ...        ...        ...             ...         ...
# 9741  CA-2015-117086 2015-11-08 2015-11-12  Standard Class    QJ-19255
# 9774  CA-2014-169019 2014-07-26 2014-07-30  Standard Class    LF-17185
# 9857  CA-2015-164301 2015-03-26 2015-03-30  Standard Class    EB-13840
# 9929  CA-2016-129630 2016-09-04 2016-09-04        Same Day    IM-15055
# 9948  CA-2017-121559 2017-06-01 2017-06-03    Second Class    HW-14935
#
#         Customer Name    Segment           City         State  Postal Code  \
# ...

# %% [markdown]
# **Get the quantity outlier**

# %%
data['Quantity'].describe()
# Out:
# count    9993.000000
# mean        3.789753
# std         2.225149
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         5.000000
# max        14.000000
# Name: Quantity, dtype: float64

# %%
QuantityLimit = data['Quantity'].mean() + (3 * data['Quantity'].std())
QuantityLimit
# Out:
# np.float64(10.46519984533301)

# %%
data[data['Quantity'] > QuantityLimit]
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 113   CA-2014-115259 2014-08-25 2014-08-27    Second Class    RC-19960
# 139   CA-2016-145583 2016-10-13 2016-10-19  Standard Class    LC-16885
# 147   CA-2016-114489 2016-12-05 2016-12-09  Standard Class    JE-16165
# 251   CA-2016-145625 2016-09-11 2016-09-17  Standard Class    KC-16540
# 342   CA-2014-122336 2014-04-13 2014-04-17    Second Class    JD-15895
# ...              ...        ...        ...             ...         ...
# 9732  CA-2014-114321 2014-08-20 2014-08-25  Standard Class    NC-18535
# 9882  CA-2014-153927 2014-08-12 2014-08-13     First Class    LL-16840
# 9895  CA-2014-115049 2014-09-26 2014-10-01  Standard Class    MM-17920
# 9941  CA-2017-164028 2017-11-24 2017-11-30  Standard Class    JL-15835
# 9979  US-2016-103674 2016-12-06 2016-12-10  Standard Class    AP-10720
#
#            Customer Name      Segment           City         State  \
# ...

# %% [markdown]
# **Get the discount outlier**

# %%
data['Discount'].describe()
# Out:
# count    9993.000000
# mean        0.156188
# std         0.206457
# min         0.000000
# 25%         0.000000
# 50%         0.200000
# 75%         0.200000
# max         0.800000
# Name: Discount, dtype: float64

# %%
DiscountLimit = data['Discount'].mean() + (3 * data['Discount'].std())
DiscountLimit
# Out:
# np.float64(0.7755601905755365)

# %%
data[data['Discount'] > DiscountLimit]
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 14    US-2015-118983 2015-11-22 2015-11-26  Standard Class    HP-14815
# 15    US-2015-118983 2015-11-22 2015-11-26  Standard Class    HP-14815
# 75    US-2017-118038 2017-12-09 2017-12-11     First Class    KB-16600
# 101   CA-2016-158568 2016-08-29 2016-09-02  Standard Class    RB-19465
# 169   CA-2014-139892 2014-09-08 2014-09-12  Standard Class    BM-11140
# ...              ...        ...        ...             ...         ...
# 9794  CA-2014-127166 2014-05-21 2014-05-23    Second Class    KH-16360
# 9795  CA-2016-125920 2016-05-21 2016-05-28  Standard Class    SH-19975
# 9808  CA-2017-145093 2017-07-21 2017-07-26  Standard Class    PT-19090
# 9835  CA-2016-126627 2016-10-10 2016-10-12     First Class    WB-21850
# 9920  CA-2016-149272 2016-03-15 2016-03-19  Standard Class    MY-18295
#
#          Customer Name      Segment         City     State  Postal Code  ...  \
# ...

# %% [markdown]
# **Get the Profit Outlier**

# %%
data['Profit'].describe()
# Out:
# count    9993.000000
# mean       28.660971
# std       234.271476
# min     -6599.978000
# 25%         1.731000
# 50%         8.671000
# 75%        29.364000
# max      8399.976000
# Name: Profit, dtype: float64

# %%
ProfitLimit = data['Profit'].mean() + (3 * data['Profit'].std())
ProfitLimit
# Out:
# np.float64(731.4753976767711)

# %%
data[data['Profit'] > ProfitLimit]
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 318   CA-2014-164973 2014-11-04 2014-11-09  Standard Class    NM-18445
# 353   CA-2016-129714 2016-09-01 2016-09-03     First Class    AB-10060
# 509   CA-2015-145352 2015-03-16 2015-03-22  Standard Class    CM-12385
# 515   CA-2017-127432 2017-01-22 2017-01-27  Standard Class    AD-10180
# 910   CA-2017-137596 2017-09-02 2017-09-07  Standard Class    BE-11335
# ...              ...        ...        ...             ...         ...
# 9273  CA-2017-146983 2017-09-02 2017-09-06  Standard Class    AH-10210
# 9615  CA-2014-128524 2014-11-11 2014-11-13     First Class    MZ-17515
# 9741  CA-2015-117086 2015-11-08 2015-11-12  Standard Class    QJ-19255
# 9929  CA-2016-129630 2016-09-04 2016-09-04        Same Day    IM-15055
# 9948  CA-2017-121559 2017-06-01 2017-06-03    Second Class    HW-14935
#
#              Customer Name      Segment           City       State  \
# ...

# %%
data['Order Delay'] = data['Ship Date'] - data['Order Date']
data
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2     CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# ...              ...        ...        ...             ...         ...
# 9989  CA-2014-110422 2014-01-21 2014-01-23    Second Class    TB-21400
# 9990  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9993  CA-2017-119914 2017-05-04 2017-05-09    Second Class    CC-12220
#
#          Customer Name    Segment             City       State  Postal Code  \
# ...

# %% [markdown]
# **Get the Delay Outlier**

# %%
data['Order Delay'].describe()
# Out:
# count                         9993
# mean     3 days 22:59:45.950165115
# std      1 days 17:56:37.317176749
# min                0 days 00:00:00
# 25%                3 days 00:00:00
# 50%                4 days 00:00:00
# 75%                5 days 00:00:00
# max                7 days 00:00:00
# Name: Order Delay, dtype: object

# %%
DelayLimit = data['Order Delay'].mean() + (3 * data['Order Delay'].std())
DelayLimit
# Out:
# Timedelta('9 days 04:49:37.901695362')

# %% [markdown]
# **No outliers in the delay**

# %%
data[data['Order Delay'] > DelayLimit]
# Out:
# Empty DataFrame
# Columns: [Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit, Ship Month, Ship Year, Order Month, Order Year, Order Delay]
# Index: []
#
# [0 rows x 24 columns]

# %%
data["Order Delay"].astype(int).plot.box()
# Out:
# <Axes: >

# %%
pd.crosstab(data['Order Month'], data['City'])
# Out:
# City         Aberdeen  Abilene  Akron  Albuquerque  Alexandria  Allen  \
# Order Month
# 1                   0        0      0            0           8      0
# 2                   0        0      5            0           0      0
# 3                   0        0      0            6           0      0
# 4                   0        0      0            0           6      0
# 5                   0        0      3            0           0      2
# 6                   0        0      1            0           0      0
# 7                   0        0      0            0           0      0
# 8                   0        0      3            0           0      0
# 9                   0        0      5            1           0      0
# 10                  0        0      2            3           0      0
# 11                  1        0      1            0           1      2
# 12                  0        1      1            4           1      0
#
# ...

# %%
pd.crosstab([data['Order Month'], data['Sub-Category']] , data['City'])
# Out:
# City                      Aberdeen  Abilene  Akron  Albuquerque  Alexandria  \
# Order Month Sub-Category
# 1           Accessories          0        0      0            0           0
#             Appliances           0        0      0            0           0
#             Art                  0        0      0            0           0
#             Binders              0        0      0            0           0
#             Bookcases            0        0      0            0           0
# ...                            ...      ...    ...          ...         ...
# 12          Paper                0        0      0            1           0
#             Phones               0        0      0            1           0
#             Storage              0        0      0            2           1
#             Supplies             0        0      0            0           0
#             Tables               0        0      0            0           0
#
# ...

# %%
pd.crosstab(data['Order Month'], data['State'])
# Out:
# State        Alabama  Arizona  Arkansas  California  Colorado  Connecticut  \
# Order Month
# 1                  3        6         6          67         4            2
# 2                  0        7         1          67         1            4
# 3                  3        6         1         133         6            7
# 4                  5       19         3         143        13            7
# 5                  6       12         4         127        12            8
# 6                  8       22        11         123         8            8
# 7                  3       24         0         130        11            8
# 8                  1       17         5         165        18            7
# 9                 10       25         6         255        25           11
# 10                 4       20         6         188        19            6
# 11                 8       29         4         284        14            6
# ...

# %%
pd.crosstab([data['Order Month'], data['Sub-Category']] , data['State'])
# Out:
# State                     Alabama  Arizona  Arkansas  California  Colorado  \
# Order Month Sub-Category
# 1           Accessories         0        1         0           4         1
#             Appliances          0        0         0           2         0
#             Art                 1        0         2          10         0
#             Binders             2        2         0           8         1
#             Bookcases           0        1         0           2         0
# ...                           ...      ...       ...         ...       ...
# 12          Paper               3        6         3          49         4
#             Phones              1        2         1          26         6
#             Storage             0        2         2          30         3
#             Supplies            1        0         0           7         1
#             Tables              0        3         0          11         1
#
# ...

# %%
pd.crosstab(data['Order Month'], data['Region'])
# Out:
# Region       Central  East  South  West
# Order Month
# 1                109    90     77   105
# 2                 70    82     52    96
# 3                177   190    124   205
# 4                137   200    133   197
# 5                191   204    136   204
# 6                170   210    131   206
# 7                169   216    101   224
# 8                149   184    114   259
# 9                291   449    202   441
# 10               188   205    129   297
# 11               371   432    227   441
# 12               301   385    194   528

# %%
pd.crosstab([data['Order Month'], data['Sub-Category']] , data['Region'])
# Out:
# Region                    Central  East  South  West
# Order Month Sub-Category
# 1           Accessories         9     9      4     8
#             Appliances          3     3      2     3
#             Art                 9    12      9    10
#             Binders            23     9     14    15
#             Bookcases           4     3      1     5
# ...                           ...   ...    ...   ...
# 12          Paper              43    50     20    79
#             Phones             27    29     13    44
#             Storage            25    27     18    50
#             Supplies            4     8      4     9
#             Tables              7    12      6    23
#
# [203 rows x 4 columns]

# %%
pd.crosstab([data['Ship Mode'], data['Ship Year']], data['Category'])
# Out:
# Category                  Furniture  Office Supplies  Technology
# Ship Mode      Ship Year
# First Class    2014              68              164          54
#                2015              57              171          65
#                2016              73              241          69
#                2017             129              334         113
# Same Day       2014              14               60          16
#                2015              29               62          18
#                2016              36               94          28
#                2017              40              110          36
# Second Class   2014              87              224          58
#                2015              85              238         101
#                2016             114              290          91
#                2017             138              397         116
#                2018               3                3           0
# ...

# %%
pd.crosstab([data['Ship Mode'], data['Category']], data['State'])
# Out:
# State                           Alabama  Arizona  Arkansas  California  \
# Ship Mode      Category
# First Class    Furniture              1        7         0          72
#                Office Supplies        6       25         5         190
#                Technology             2       10         5          60
# Same Day       Furniture              0        4         0          29
#                Office Supplies        0        8         2          79
#                Technology             1        4         0          11
# Second Class   Furniture              3        4         0          83
#                Office Supplies       11       15         8         246
#                Technology             4        8         2          66
# Standard Class Furniture              7       34         9         260
#                Office Supplies       19       79        21         683
#                Technology             7       26         8         222
#
# ...

# %%
pd.crosstab([data['Ship Mode'], data['Category']], data['Segment'])
# Out:
# Segment                         Consumer  Corporate  Home Office
# Ship Mode      Category
# First Class    Furniture             164        104           59
#                Office Supplies       456        291          163
#                Technology            149         90           62
# Same Day       Furniture              66         28           25
#                Office Supplies       193         69           64
#                Technology             58         17           23
# Second Class   Furniture             236        121           70
#                Office Supplies       603        372          177
#                Technology            181        116           69
# Standard Class Furniture             647        393          207
#                Office Supplies      1875       1088          675
#                Technology            563        331          188

# %%
pd.crosstab([data['Order Year'], data['Category']], data['Segment'])
# Out:
# Segment                     Consumer  Corporate  Home Office
# Order Year Category
# 2014       Furniture             231        123           66
#            Office Supplies       642        388          187
#            Technology            197        100           58
# 2015       Furniture             238        139           75
#            Office Supplies       656        375          210
#            Technology            231        122           56
# 2016       Furniture             292        186           84
#            Office Supplies       808        466          292
#            Technology            228        141           90
# 2017       Furniture             352        198          136
#            Office Supplies      1021        591          390
#            Technology            295        191          138

# %%
pd.crosstab([data['Order Year'], data['Category']], data['Segment']).plot.bar()
# Out:
# <Axes: xlabel='Order Year,Category'>

# %%
data.groupby('Order Year')[['Sales', 'Profit', 'Discount', 'Quantity']].agg(['sum', 'max', 'min', 'mean'])
# Out:
#                   Sales                                   Profit             \
#                     sum       max    min        mean         sum        max
# Order Year
# 2014        483966.1261  22638.48  0.852  242.954883  49556.0329  4630.4755
# 2015        470532.5090   6354.95  0.984  223.849909  61618.6037  3177.4750
# 2016        609205.5980  17499.95  0.836  235.487282  81795.1743  8399.9760
# 2017        733215.2552  13999.96  0.444  221.381418  93439.2696  6719.9808
#
#                                  Discount                     Quantity      \
#                   min       mean      sum  max  min      mean      sum max
# Order Year
# 2014       -3701.8928  24.877527   315.16  0.8  0.0  0.158213     7579  14
# 2015       -2639.9912  29.314274   327.09  0.8  0.0  0.155609     7979  14
# 2016       -6599.9780  31.617771   400.32  0.8  0.0  0.154743     9837  14
# 2017       -3839.9904  28.212340   518.22  0.8  0.0  0.156467    12476  14
#
#
#            min      mean
# ...

# %%
data.groupby('State')[['Sales', 'Profit']].agg(['sum', 'max', 'min', 'mean'])
# Out:
#                             Sales                                    \
#                               sum        max       min         mean
# State
# Alabama                19510.6400   3040.000     3.620   319.846557
# Arizona                35282.0010   1879.960     1.408   157.508933
# Arkansas               11678.1300   1793.980     4.300   194.635500
# California            457687.6315   8187.650     0.990   228.729451
# Colorado               32108.1180   2549.985     1.080   176.418231
# Connecticut            13384.3570   1133.350     3.520   163.223866
# Delaware               27451.0690  10499.970     3.380   285.948635
# District of Columbia    2865.0200   1379.920     9.640   286.502000
# Florida                89473.7080  22638.480     1.167   233.612815
# Georgia                49095.8400   6354.950     1.780   266.825217
# Idaho                   4382.4860   1128.390     3.304   208.689810
# Illinois               80166.1010   2799.960     0.836   162.939230
# ...

# %%
data.groupby('Category')[['Sales', 'Profit']].agg(['sum', 'max', 'min', 'mean'])
# Out:
#                        Sales                                     Profit  \
#                          sum        max    min        mean          sum
# Category
# Furniture        741718.4233   4416.174  1.892  349.867181   18463.3316
# Office Supplies  719047.0320   9892.740  0.444  119.324101  122490.8008
# Technology       836154.0330  22638.480  0.990  452.709276  145454.9481
#
#
#                       max        min       mean
# Category
# Furniture        1013.127 -1862.3124   8.709119
# Office Supplies  4946.370 -3701.8928  20.327050
# Technology       8399.976 -6599.9780  78.752002

# %%
data.groupby('State')['Order Delay'].mean()
# Out:
# State
# Alabama                4 days 02:45:14.754098360
# Arizona                4 days 01:42:51.428571428
# Arkansas                         4 days 03:12:00
# California             3 days 20:48:34.542728635
# Colorado               3 days 16:21:05.934065934
# Connecticut            3 days 14:20:29.268292682
# Delaware                         4 days 06:30:00
# District of Columbia             5 days 16:48:00
# Florida                3 days 22:44:48.250652741
# Georgia                3 days 20:05:13.043478260
# Idaho                            3 days 16:00:00
# Illinois               4 days 02:52:40.975609756
# Indiana                4 days 08:03:13.288590604
# Iowa                             4 days 08:48:00
# Kansas                           3 days 23:00:00
# Kentucky               3 days 20:32:48.345323741
# Louisiana              3 days 01:08:34.285714285
# Maine                            5 days 00:00:00
# Maryland               4 days 00:27:25.714285714
# ...

# %%
data.groupby('Region')['Order Delay'].mean()
# Out:
# Region
# Central   4 days 01:23:41.093413689
# East      3 days 21:48:29.589041095
# South     3 days 22:59:33.333333333
# West      3 days 22:18:50.689978145
# Name: Order Delay, dtype: timedelta64[ns]

# %%
data.groupby('Region')['Order Delay'].mean().plot.bar()
# Out:
# <Axes: xlabel='Region'>
